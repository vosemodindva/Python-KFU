# %% [markdown]
# <a href="https://colab.research.google.com/github/vosemodindva/Python-KFU/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3. Условный оператор: группа If
# 4. Оператор выбора: группа Case

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

x = int(input())

if (x > -4):
    f = math.cos(2*x) + 9
else:
    f = - (math.cos(x) / (x - 9))
print(f)
# Out:
# -10
# -0.044161659425076445

# %%
x = int(input())
a = int(input())
B = int(input())
C = int(input())

if (x == a):
    print('Цена за пользование услугами = ', B)
else:
    if (x > a):
        print('Цена за пользование услугами из-за превышения нормы = ', C)
# Out:
# 50
# 30
# 200
# 400
# Цена за пользование услугами из-за превышения нормы =  400

# %%
a1 = int(input())
a2 = int(input())
a3 = int(input())
a4 = int(input())

if (a1 == a2 == a3 != a4):
    n = 4
elif (a1 == a2 == a4 != a3):
    n = 3
elif (a1 == a3 == a4 != a2):
    n = 2
elif (a2 == a3 == a4 != a1):
    n = 1
print('Номер числа, которое отлчается от всех', n)
# Out:
# 2
# 5
# 2
# 2
# Номер числа, которое отлчается от всех 2

# %%
x = int(input())
a = int(input())
sum = 0

for n in range(1, 3):
    sum += x % 10
    x = x // 10
if (sum > 9):
    print('a) Yes')
else:
    print('a) No')

if (sum > a):
    print('b) Yes')
else:
    print('b) No')
# Out:
# 56
# 13
# a) Yes
# b) No

# %%
a, b = 2, 3
c, d = 5, 6
e, f = 4, 5
black_piece = "queen"


if abs(a - e) != abs(b - f):
    print("Белый слон не может пойти на это поле")
else:

    is_under_attack = False

    if black_piece == "bishop":
        if abs(c - e) == abs(d - f):
            is_under_attack = True
    elif black_piece == "queen":
        if c == e or d == f or abs(c - e) == abs(d - f):
            is_under_attack = True
    elif black_piece == "knight":
        if (abs(c - e) == 2 and abs(d - f) == 1) or (abs(c - e) == 1 and abs(d - f) == 2):
            is_under_attack = True

    if is_under_attack:
        print("Белый слон может пойти на поле, но оно под ударом черной фигуры")
    else:
        print("Белый слон может безопасно пойти на поле")
# Out:
# Белый слон может пойти на поле, но оно под ударом черной фигуры
