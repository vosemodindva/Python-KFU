# %% [markdown]
# <a href="https://colab.research.google.com/github/vosemodindva/Python-KFU/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ТЕМА: 2. Целые числа: группа Integer

# %%
import math

x = int(input())
t = x*(1-x)+x*(x*x -1) / (8*x*x)

print(t)
# Out:
# 2
# -1.8125

# %%
import math

x = int(input())
w = math.log(math.sqrt(x - 5)) + math.log(math.sqrt(2*x-3))

print(w)
# Out:
# 10
# 2.2213256282451583

# %%
import math

x = math.pi

for i in range(1, 5):
    x *= x
    print(x)
# Out:
# 9.869604401089358
# 97.40909103400243
# 9488.531016070572
# 90032220.84293324

# %%
x = int(input())
x = x % 3600
print(x)
# Out:
# 72364
# 364

# %%
a = int(input())
b = int(input())

x = (a + b) % 2
print(x)
# Out:
# 23
# 4
# 1
